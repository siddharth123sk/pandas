# %%
import pandas as pd
import numpy as np

# %%
A = [[1,2,3], [1,2,3]]

# %%
print(A)
# Out:
# [[1, 2, 3], [1, 2, 3]]

# %%
A = np.array(A)

# %%
A
# Out:
# array([[1, 2, 3],
#        [1, 2, 3]])

# %%
data = {'a' : [1,2,3,4],
        'b' : [3,4,5,6]
       }

# %%
mydataframe = pd.DataFrame(data)

# %%
mydataframe
# Out:
#    a  b
# 0  1  3
# 1  2  4
# 2  3  5
# 3  4  6

# %%
# importing data into a Dataframe from a csv file
df1 = pd.read_csv('data.csv')

# %%
df1
# Out:
#      5125  5125.1  1
# 0    6210    6210  1
# 1    3125    3125  1
# 2    2210    2210  1
# 3    3125    3125  1
# 4    2340    2340  1
# 5    3455    3455  1
# 6    2232    2232  1
# 7    1231    1231  1
# 8    1213    1213  1
# 9   10125   10125  2
# 10   6410    6410  2
# 11   5845    5845  2
# 12   6570    6570  2
# 13   8375    8375  2
# 14   9545    9545  2
# 15   3460    3460  2
# 16   8678    8678  2
# 17   6800    6800  2
# 18  12403   12403  2
# 19  14325   14325  3
# 20  16304   16304  3
# 21  18232   18232  3
# 22  11233   11233  3
# 23  23232   23232  3
# 24  22223   22223  3
# 25  15360   15360  3
# 26  17120   17120  3
# 27  15302   15302  3
# 28  12303   12303  3

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#       5125,5125,1
# 0     6210,6210,1
# 1     3125,3125,1
# 2     2210,2210,1
# 3     3125,3125,1
# 4     2340,2340,1
# 5     3455,3455,1
# 6     2232,2232,1
# 7     1231,1231,1
# 8     1213,1213,1
# 9   10125,10125,2
# 10    6410,6410,2
# 11    5845,5845,2
# 12    6570,6570,2
# 13    8375,8375,2
# 14    9545,9545,2
# 15    3460,3460,2
# 16    8678,8678,2
# 17    6800,6800,2
# 18  12403,12403,2
# 19  14325,14325,3
# 20  16304,16304,3
# 21  18232,18232,3
# 22  11233,11233,3
# 23  23232,23232,3
# 24  22223,22223,3
# 25  15360,15360,3
# 26  17120,17120,3
# 27  15302,15302,3
# 28  12303,12303,3

# %%
df3 = pd.read_excel('data.xlsx')

# %%
df3
# Out:
#     Unnamed: 0                                        Institution  \
# 0          1.0                                                USC
# 1          2.0                                           Maryland
# 2          3.0                                                WPI
# 3          4.0                                       Northwestern
# 4          5.0                                   Oregon State uin
# 5          6.0                                              Upenn
# 6          7.0                                            Buffalo
# 7          8.0                                               SUTD
# 8          9.0                                       Northeastern
# 9         10.0                                                NaN
# 10         NaN  https://www.gradschoolhub.com/best/robotics-en...
# 11         NaN                                                NaN
# 12         NaN                                                CMU
# ...

# %%
df4 = pd.read_csv('data.csv')

# %%
df4
# Out:
#      5125  5125.1  1
# 0    6210    6210  1
# 1    3125    3125  1
# 2    2210    2210  1
# 3    3125    3125  1
# 4    2340    2340  1
# 5    3455    3455  1
# 6    2232    2232  1
# 7    1231    1231  1
# 8    1213    1213  1
# 9   10125   10125  2
# 10   6410    6410  2
# 11   5845    5845  2
# 12   6570    6570  2
# 13   8375    8375  2
# 14   9545    9545  2
# 15   3460    3460  2
# 16   8678    8678  2
# 17   6800    6800  2
# 18  12403   12403  2
# 19  14325   14325  3
# 20  16304   16304  3
# 21  18232   18232  3
# 22  11233   11233  3
# 23  23232   23232  3
# 24  22223   22223  3
# 25  15360   15360  3
# 26  17120   17120  3
# 27  15302   15302  3
# 28  12303   12303  3

# %%
column_names = ['event_date', 'operation', 'country', 'UserID', 'Source', 'Topic']

# %%
df = pd.read_csv('data.csv', delimiter = ';', names = column_names)

# %%
df
# Out:
#        event_date  operation  country  UserID  Source  Topic
# 0     5125,5125,1        NaN      NaN     NaN     NaN    NaN
# 1     6210,6210,1        NaN      NaN     NaN     NaN    NaN
# 2     3125,3125,1        NaN      NaN     NaN     NaN    NaN
# 3     2210,2210,1        NaN      NaN     NaN     NaN    NaN
# 4     3125,3125,1        NaN      NaN     NaN     NaN    NaN
# 5     2340,2340,1        NaN      NaN     NaN     NaN    NaN
# 6     3455,3455,1        NaN      NaN     NaN     NaN    NaN
# 7     2232,2232,1        NaN      NaN     NaN     NaN    NaN
# 8     1231,1231,1        NaN      NaN     NaN     NaN    NaN
# 9     1213,1213,1        NaN      NaN     NaN     NaN    NaN
# 10  10125,10125,2        NaN      NaN     NaN     NaN    NaN
# 11    6410,6410,2        NaN      NaN     NaN     NaN    NaN
# 12    5845,5845,2        NaN      NaN     NaN     NaN    NaN
# 13    6570,6570,2        NaN      NaN     NaN     NaN    NaN
# ...

# %%
df.head(10)
# Out:
#     event_date  operation  country  UserID  Source  Topic
# 0  5125,5125,1        NaN      NaN     NaN     NaN    NaN
# 1  6210,6210,1        NaN      NaN     NaN     NaN    NaN
# 2  3125,3125,1        NaN      NaN     NaN     NaN    NaN
# 3  2210,2210,1        NaN      NaN     NaN     NaN    NaN
# 4  3125,3125,1        NaN      NaN     NaN     NaN    NaN
# 5  2340,2340,1        NaN      NaN     NaN     NaN    NaN
# 6  3455,3455,1        NaN      NaN     NaN     NaN    NaN
# 7  2232,2232,1        NaN      NaN     NaN     NaN    NaN
# 8  1231,1231,1        NaN      NaN     NaN     NaN    NaN
# 9  1213,1213,1        NaN      NaN     NaN     NaN    NaN

# %%
df.tail(5)
# Out:
#        event_date  operation  country  UserID  Source  Topic
# 25  22223,22223,3        NaN      NaN     NaN     NaN    NaN
# 26  15360,15360,3        NaN      NaN     NaN     NaN    NaN
# 27  17120,17120,3        NaN      NaN     NaN     NaN    NaN
# 28  15302,15302,3        NaN      NaN     NaN     NaN    NaN
# 29  12303,12303,3        NaN      NaN     NaN     NaN    NaN

# %%
df.columns
# Out:
# Index(['event_date', 'operation', 'country', 'UserID', 'Source', 'Topic'], dtype='object')

# %%
#df[['event_data']]

# %%
#df.event_data

# %%
# grouping by data
#df.data_groupby('country')
